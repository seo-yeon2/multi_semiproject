# %%
# data
import numpy as np
import pandas as pd

# visualization
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# warning 
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_excel("main.xlsx")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   자치구(구)      11500 non-null  object
#  1   날짜          11500 non-null  int64
#  2   1hr 최대 강수량  11500 non-null  float64
#  3   일평균 강수량     11500 non-null  float64
#  4   경사도         11500 non-null  float64
#  5   고도(해발고도)    11500 non-null  float64
#  6   불투수면        11500 non-null  float64
#  7   녹지 면적율      11500 non-null  float64
#  8   하천 면적율      11500 non-null  float64
#  9   복개하천 개수     11500 non-null  int64
#  10  맨홀개수        11500 non-null  int64
#  11  빗물받이 개수     11500 non-null  int64
#  12  빗물 펌프 개수    11500 non-null  int64
#  13  하수관로 비율     11500 non-null  object
# dtypes: float64(7), int64(5), object(2)
# memory usage: 1.2+ MB

# %%
df1 = df.drop_duplicates('녹지 면적율')
df1
df2 = df1[['날짜','자치구(구)','녹지 면적율']]
df2
# Out:
#              날짜 자치구(구)    녹지 면적율
# 0      20180601     종로  0.009418
# 92     20180601      중  0.022957
# 184    20180601     용산  0.016664
# 276    20180601     성동  0.017750
# 368    20180601     광진  0.017115
# ...         ...    ...       ...
# 11040  20220601     관악  0.029419
# 11132  20220601     서초  0.027221
# 11224  20220601     강남  0.029274
# 11316  20220601     송파  0.096774
# 11408  20220601     강동  0.035874
#
# [119 rows x 3 columns]

# %%
df2.to_excel('test.xlsx')

# %%
df = pd.read_excel("test.xlsx")
df
# Out:
#      Unnamed: 0        날짜 자치구(구)    녹지 면적율
# 0             0  20180601     종로  0.009418
# 1            92  20180601      중  0.022957
# 2           184  20180601     용산  0.016664
# 3           276  20180601     성동  0.017750
# 4           368  20180601     광진  0.017115
# ..          ...       ...    ...       ...
# 120       11592  20220601     관악  0.029419
# 121       11684  20220601     서초  0.027221
# 122       11776  20220601     강남  0.029274
# 123       11868  20220601     송파  0.096774
# 124       11960  20220601     강동  0.035874
#
# [125 rows x 4 columns]

# %%
# 데이터 프레임을 25개씩 끊어서 새로운 데이터 프레임 생성
num_subframes = 5
subframe_size = len(df) // num_subframes  # 각 데이터 프레임의 크기 계산

subframes = [df.iloc[i*subframe_size:(i+1)*subframe_size] for i in range(num_subframes)]

# 각각의 데이터 프레임을 다른 변수에 저장
df1, df2, df3, df4, df5 = subframes

new_df1 = df1.copy()  
new_df1['자치구(구)'] = new_df1['자치구(구)'] + '구'

new_df2 = df2.copy()  
new_df2['자치구(구)'] = new_df2['자치구(구)'] + '구'

new_df3 = df3.copy()  
new_df3['자치구(구)'] = new_df3['자치구(구)'] + '구'

new_df4 = df4.copy()  
new_df4['자치구(구)'] = new_df4['자치구(구)'] + '구'

new_df5 = df5.copy()  
new_df5['자치구(구)'] = new_df5['자치구(구)'] + '구'

new_df5
# Out:
#      Unnamed: 0        날짜 자치구(구)    녹지 면적율
# 100        9752  20220601    종로구  0.008689
# 101        9844  20220601     중구  0.012675
# 102        9936  20220601    용산구  0.010724
# 103       10028  20220601    성동구  0.013973
# 104       10120  20220601    광진구  0.015830
# 105       10212  20220601   동대문구  0.004315
# 106       10304  20220601    중랑구  0.008163
# 107       10396  20220601    성북구  0.004382
# 108       10488  20220601    강북구  0.000923
# 109       10580  20220601    도봉구  0.008378
# 110       10672  20220601    노원구  0.022998
# 111       10764  20220601    은평구  0.004418
# 112       10856  20220601   서대문구  0.004578
# 113       10948  20220601    마포구  0.108200
# 114       11040  20220601    양천구  0.050820
# 115       11132  20220601    강서구  0.037256
# 116       11224  20220601    구로구  0.019508
# 117       11316  20220601    금천구  0.032182
# 118       11408  20220601   영등포구  0.069282
# 119       11500  20220601    동작구  0.003568
# 120       11592  20220601    관악구  0.029419
# 121       11684  20220601    서초구  0.027221
# 122       11776  20220601    강남구  0.029274
# 123       11868  20220601    송파구  0.096774
# 124       11960  20220601    강동구  0.035874

# %%
# 위도경도 매핑

locs = {
    '종로구': (37.595176, 126.977262),
    '중구': (37.560229, 126.995971),
    '용산구':(37.531486, 126.980292),
    '성동구':  (37.550983, 127.041041),
    '광진구': (37.546714, 127.085754),
    '동대문구':  (37.581916, 127.054846),
    '중랑구': (37.597810, 127.092896),
    '성북구': (37.605636, 127.017551),
    '강북구':  (37.643463, 127.011188),
    '도봉구':  (37.6691, 127.0324),
    '노원구':   (37.6524, 127.075),
    '은평구': (37.619161, 126.927011),
    '서대문구': (37.5778, 126.9391),
    '마포구': (37.5593, 126.9083),
    '양천구': (37.5248, 126.8553),
    '강서구':    (37.5612, 126.8229),
    '구로구':   (37.4944, 126.8564),
    '금천구':   (37.4605, 126.9008),
    '영등포구':   (37.5223, 126.9102),
    '동작구':   (37.4988, 126.9516),
    '관악구':   (37.4673, 126.9454),
    '서초구':   (37.4733, 127.0312),
    '강남구':   (37.4966, 127.063),
    '송파구':   (37.5056, 127.1153),
    '강동구':   (37.5504, 127.147),
}

locs
# Out:
# {'종로구': (37.595176, 126.977262),
#  '중구': (37.560229, 126.995971),
#  '용산구': (37.531486, 126.980292),
#  '성동구': (37.550983, 127.041041),
#  '광진구': (37.546714, 127.085754),
#  '동대문구': (37.581916, 127.054846),
#  '중랑구': (37.59781, 127.092896),
#  '성북구': (37.605636, 127.017551),
#  '강북구': (37.643463, 127.011188),
#  '도봉구': (37.6691, 127.0324),
#  '노원구': (37.6524, 127.075),
#  '은평구': (37.619161, 126.927011),
#  '서대문구': (37.5778, 126.9391),
#  '마포구': (37.5593, 126.9083),
#  '양천구': (37.5248, 126.8553),
#  '강서구': (37.5612, 126.8229),
#  '구로구': (37.4944, 126.8564),
#  '금천구': (37.4605, 126.9008),
#  '영등포구': (37.5223, 126.9102),
#  '동작구': (37.4988, 126.9516),
#  '관악구': (37.4673, 126.9454),
#  '서초구': (37.4733, 127.0312),
#  '강남구': (37.4966, 127.063),
#  '송파구': (37.5056, 127.1153),
#  '강동구': (37.5504, 127.147)}

# %%
# 연도별 녹지 면적율
# 2018
import folium


geo_json = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'



m = folium.Map(location=[37.5642135, 127.0016985])

folium.Choropleth(geo_data = geo_json,
                  name = 'choropleth',
                  data = new_df1,
                  columns=['자치구(구)', '녹지 면적율'],
                  key_on = 'feature.properties.name',
                  fill_color = 'YlGn',
                  fill_opacity = 0.7,
                  line_opacity = 0.2,
).add_to(m)

folium.LayerControl().add_to(m)

for key, value in locs.items():
    text = f"{key}: {new_df1.loc[new_df1['자치구(구)'] == key, '녹지 면적율'].values[0]}"
    folium.Marker(
        location=value,
        icon=folium.DivIcon(
            icon_size=(0, 0),
            icon_anchor=(0, 0),
            html=f'<div style="font-size: 0.8rem; color: black; background-color:rgba(255, 255, 255, 0.2); width:85px; text-align:center; margin:0px;"><b>{text}</b></div>'
        )
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea2f07d21695bc9643a91db95483cf6f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea2f07d21695bc9643a91db95483cf6f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea2f07d21695bc9643a91db95483cf6f = L.map(
#                 &quot;map_ea2f07d21695bc9643a91db95483cf6f&quot;,
#                 {
#                     center: [37.5642135, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0d82ad67cf49070bb3ec9934727e0db = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ea2f07d21695bc9643a91db95483cf6f);
#
#
#             var choropleth_d703ab190895d5913aa589449fa561fb = L.featureGroup(
#                 {}
#             ).addTo(map_ea2f07d21695bc9643a91db95483cf6f);
#
#
#         function geo_json_0e9349fdb4138db55ee0d7c58a2bd13a_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11250&quot;: case &quot;11180&quot;: case &quot;11160&quot;: case &quot;11020&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11230&quot;: case &quot;11140&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11210&quot;: case &quot;11090&quot;: case &quot;11010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11200&quot;: case &quot;11110&quot;: case &quot;11050&quot;: case &quot;11040&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11130&quot;: case &quot;11120&quot;: case &quot;11100&quot;: case &quot;11080&quot;: case &quot;11030&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_0e9349fdb4138db55ee0d7c58a2bd13a_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_0e9349fdb4138db55ee0d7c58a2bd13a = L.geoJson(null, {
#                 onEachFeature: geo_json_0e9349fdb4138db55ee0d7c58a2bd13a_onEachFeature,
#
#                 style: geo_json_0e9349fdb4138db55ee0d7c58a2bd13a_styler,
#         });
#
#         function geo_json_0e9349fdb4138db55ee0d7c58a2bd13a_add (data) {
#             geo_json_0e9349fdb4138db55ee0d7c58a2bd13a
#                 .addData(data)
#                 .addTo(choropleth_d703ab190895d5913aa589449fa561fb);
#         }
#             geo_json_0e9349fdb4138db55ee0d7c58a2bd13a_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.151

# %%
# 2019
import folium

geo_json = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'



m = folium.Map(location=[37.5642135, 127.0016985])

folium.Choropleth(geo_data = geo_json,
                  name = 'choropleth',
                  data = new_df2,
                  columns=['자치구(구)', '녹지 면적율'],
                  key_on = 'feature.properties.name',
                  fill_color = 'YlGn',
                  fill_opacity = 0.7,
                  line_opacity = 0.2,
).add_to(m)

for key, value in locs.items():
    text = f"{key}: {new_df2.loc[new_df2['자치구(구)'] == key, '녹지 면적율'].values[0]}"
    folium.Marker(
        location=value,
        icon=folium.DivIcon(
            icon_size=(0, 0),
            icon_anchor=(0, 0),
            html=f'<div style="font-size: 1.0rem; color: black; background-color:rgba(255, 255, 255, 0.2); width:85px; text-align:center; margin:0px;"><b>{text}</b></div>'
        )
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef9039f0dbd7aa9086e26027e50ea336 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef9039f0dbd7aa9086e26027e50ea336&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef9039f0dbd7aa9086e26027e50ea336 = L.map(
#                 &quot;map_ef9039f0dbd7aa9086e26027e50ea336&quot;,
#                 {
#                     center: [37.5642135, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1bc652b65d1325ce7105cbd2bdd481a7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_ef9039f0dbd7aa9086e26027e50ea336);
#
#
#             var choropleth_6964404f09fbd002e46fd824688c78c0 = L.featureGroup(
#                 {}
#             ).addTo(map_ef9039f0dbd7aa9086e26027e50ea336);
#
#
#         function geo_json_468cc4c8da63fec4502c632642cf2ef1_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11250&quot;: case &quot;11180&quot;: case &quot;11160&quot;: case &quot;11020&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11230&quot;: case &quot;11140&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11210&quot;: case &quot;11090&quot;: case &quot;11010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11200&quot;: case &quot;11110&quot;: case &quot;11050&quot;: case &quot;11040&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11130&quot;: case &quot;11120&quot;: case &quot;11100&quot;: case &quot;11080&quot;: case &quot;11030&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_468cc4c8da63fec4502c632642cf2ef1_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_468cc4c8da63fec4502c632642cf2ef1 = L.geoJson(null, {
#                 onEachFeature: geo_json_468cc4c8da63fec4502c632642cf2ef1_onEachFeature,
#
#                 style: geo_json_468cc4c8da63fec4502c632642cf2ef1_styler,
#         });
#
#         function geo_json_468cc4c8da63fec4502c632642cf2ef1_add (data) {
#             geo_json_468cc4c8da63fec4502c632642cf2ef1
#                 .addData(data)
#                 .addTo(choropleth_6964404f09fbd002e46fd824688c78c0);
#         }
#             geo_json_468cc4c8da63fec4502c632642cf2ef1_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.151

# %%
# 2020
import folium

geo_json = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'



m = folium.Map(location=[37.5642135, 127.0016985])

folium.Choropleth(geo_data = geo_json,
                  name = 'choropleth',
                  data = new_df3,
                  columns=['자치구(구)', '녹지 면적율'],
                  key_on = 'feature.properties.name',
                  fill_color = 'YlGn',
                  fill_opacity = 0.7,
                  line_opacity = 0.2,
).add_to(m)

for key, value in locs.items():
    text = f"{key}: {new_df3.loc[new_df3['자치구(구)'] == key, '녹지 면적율'].values[0]}"
    folium.Marker(
        location=value,
        icon=folium.DivIcon(
            icon_size=(0, 0),
            icon_anchor=(0, 0),
            html=f'<div style="font-size: 1.0rem; color: black; background-color:rgba(255, 255, 255, 0.2); width:85px; text-align:center; margin:0px;"><b>{text}</b></div>'
        )
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd47c7aba1e376d5e35d17a9c9a3ff46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd47c7aba1e376d5e35d17a9c9a3ff46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd47c7aba1e376d5e35d17a9c9a3ff46 = L.map(
#                 &quot;map_fd47c7aba1e376d5e35d17a9c9a3ff46&quot;,
#                 {
#                     center: [37.5642135, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_575eea26228cb8d8496a027281432e87 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_fd47c7aba1e376d5e35d17a9c9a3ff46);
#
#
#             var choropleth_4e22ec8f45bc70af0bf9fa743f8e0cbf = L.featureGroup(
#                 {}
#             ).addTo(map_fd47c7aba1e376d5e35d17a9c9a3ff46);
#
#
#         function geo_json_e2f9f2e9985c49d5ca038ef57f5710b3_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11250&quot;: case &quot;11180&quot;: case &quot;11160&quot;: case &quot;11150&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11230&quot;: case &quot;11140&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11210&quot;: case &quot;11090&quot;: case &quot;11010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11200&quot;: case &quot;11110&quot;: case &quot;11050&quot;: case &quot;11040&quot;: case &quot;11020&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11130&quot;: case &quot;11120&quot;: case &quot;11100&quot;: case &quot;11080&quot;: case &quot;11030&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e2f9f2e9985c49d5ca038ef57f5710b3_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e2f9f2e9985c49d5ca038ef57f5710b3 = L.geoJson(null, {
#                 onEachFeature: geo_json_e2f9f2e9985c49d5ca038ef57f5710b3_onEachFeature,
#
#                 style: geo_json_e2f9f2e9985c49d5ca038ef57f5710b3_styler,
#         });
#
#         function geo_json_e2f9f2e9985c49d5ca038ef57f5710b3_add (data) {
#             geo_json_e2f9f2e9985c49d5ca038ef57f5710b3
#                 .addData(data)
#                 .addTo(choropleth_4e22ec8f45bc70af0bf9fa743f8e0cbf);
#         }
#             geo_json_e2f9f2e9985c49d5ca038ef57f5710b3_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.5

# %%
# 2021
import folium

geo_json = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'



m = folium.Map(location=[37.5665, 126.9780])

folium.Choropleth(geo_data = geo_json,
                  name = 'choropleth',
                  data = new_df4,
                  columns=['자치구(구)', '녹지 면적율'],
                  key_on = 'feature.properties.name',
                  fill_color = 'YlGn',
                  fill_opacity = 0.7,
                  line_opacity = 0.2,
).add_to(m)

for key, value in locs.items():
    text = f"{key}: {new_df4.loc[new_df4['자치구(구)'] == key, '녹지 면적율'].values[0]}"
    folium.Marker(
        location=value,
        icon=folium.DivIcon(
            icon_size=(0, 0),
            icon_anchor=(0, 0),
            html=f'<div style="font-size: 1.0rem; color: black; background-color:rgba(255, 255, 255, 0.2); width:85px; text-align:center; margin:0px;"><b>{text}</b></div>'
        )
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44c2b812a5e0f54b8568cc1e395427b9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44c2b812a5e0f54b8568cc1e395427b9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44c2b812a5e0f54b8568cc1e395427b9 = L.map(
#                 &quot;map_44c2b812a5e0f54b8568cc1e395427b9&quot;,
#                 {
#                     center: [37.5665, 126.978],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ccb2f0d413d1873d37380ddcfc3a477c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_44c2b812a5e0f54b8568cc1e395427b9);
#
#
#             var choropleth_8dd3da501db9f26d180bf7c2235c2891 = L.featureGroup(
#                 {}
#             ).addTo(map_44c2b812a5e0f54b8568cc1e395427b9);
#
#
#         function geo_json_d357bf7a77ca5666f40376a4be36d14e_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11250&quot;: case &quot;11160&quot;: case &quot;11150&quot;: case &quot;11020&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11240&quot;: case &quot;11220&quot;: case &quot;11190&quot;: case &quot;11180&quot;: case &quot;11170&quot;: case &quot;11070&quot;: case &quot;11060&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11230&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11210&quot;: case &quot;11100&quot;: case &quot;11090&quot;: case &quot;11010&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11140&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d357bf7a77ca5666f40376a4be36d14e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d357bf7a77ca5666f40376a4be36d14e = L.geoJson(null, {
#                 onEachFeature: geo_json_d357bf7a77ca5666f40376a4be36d14e_onEachFeature,
#
#                 style: geo_json_d357bf7a77ca5666f40376a4be36d14e_styler,
#         });
#
#         function geo_json_d357bf7a77ca5666f40376a4be36d14e_add (data) {
#             geo_json_d357bf7a77ca5666f40376a4be36d14e
#                 .addData(data)
#                 .addTo(choropleth_8dd3da501db9f26d180bf7c2235c2891);
#         }
#             geo_json_d357bf7a77ca5666f40376a4be36d14e_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416

# %%
# 2022
import folium

geo_json = 'https://raw.githubusercontent.com/southkorea/seoul-maps/master/kostat/2013/json/seoul_municipalities_geo_simple.json'



m = folium.Map(location=[37.5642135, 127.0016985])

folium.Choropleth(geo_data = geo_json,
                  name = 'choropleth',
                  data = new_df5,
                  columns=['자치구(구)', '녹지 면적율'],
                  key_on = 'feature.properties.name',
                  fill_color = 'YlGn',
                  fill_opacity = 0.7,
                  line_opacity = 0.2,
).add_to(m)

for key, value in locs.items():
    text = f"{key}: {new_df5.loc[new_df5['자치구(구)'] == key, '녹지 면적율'].values[0]}"
    folium.Marker(
        location=value,
        icon=folium.DivIcon(
            icon_size=(0, 0),
            icon_anchor=(0, 0),
            html=f'<div style="font-size: 1.0rem; color: black; background-color:rgba(255, 255, 255, 0.2); width:85px; text-align:center; margin:0px;"><b>{text}</b></div>'
        )
    ).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_520cfd65ef552096a01a4a14c0895168 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_520cfd65ef552096a01a4a14c0895168&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_520cfd65ef552096a01a4a14c0895168 = L.map(
#                 &quot;map_520cfd65ef552096a01a4a14c0895168&quot;,
#                 {
#                     center: [37.5642135, 127.0016985],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a64a5ece45afd7c9192efb44ffeb73c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_520cfd65ef552096a01a4a14c0895168);
#
#
#             var choropleth_eea3e6194959b7b5e93d0d3c5b8c433f = L.featureGroup(
#                 {}
#             ).addTo(map_520cfd65ef552096a01a4a14c0895168);
#
#
#         function geo_json_efe9b4cb70c664b4aa8bcea6ee5ed488_styler(feature) {
#             switch(feature.properties.code) {
#                 case &quot;11250&quot;: case &quot;11230&quot;: case &quot;11220&quot;: case &quot;11210&quot;: case &quot;11180&quot;: case &quot;11170&quot;: case &quot;11110&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11240&quot;: case &quot;11140&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11190&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;11160&quot;: case &quot;11150&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_efe9b4cb70c664b4aa8bcea6ee5ed488_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_efe9b4cb70c664b4aa8bcea6ee5ed488 = L.geoJson(null, {
#                 onEachFeature: geo_json_efe9b4cb70c664b4aa8bcea6ee5ed488_onEachFeature,
#
#                 style: geo_json_efe9b4cb70c664b4aa8bcea6ee5ed488_styler,
#         });
#
#         function geo_json_efe9b4cb70c664b4aa8bcea6ee5ed488_add (data) {
#             geo_json_efe9b4cb70c664b4aa8bcea6ee5ed488
#                 .addData(data)
#                 .addTo(choropleth_eea3e6194959b7b5e93d0d3c5b8c433f);
#         }
#             geo_json_efe9b4cb70c664b4aa8bcea6ee5ed488_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[127.11519584981606, 37.557533180704915], [127.11879551821994, 37.557222485451305], [127.12146867175024, 37.55986003393365], [127.12435254630417, 37.56144246249796], [127.13593925898998, 37.56564793048277], [127.14930548011061, 37.56892250303897], [127.15511020940411, 37.57093642128295], [127.16683184366129, 37.57672487388627], [127.17038810813094, 37.576465605301046], [127.17607118428914, 37.57678573961056], [127.17905504160184, 37.57791388161732], [127.17747787800164, 37.57448983055031], [127.1781775408844, 37.571481967974336], [127.17995281860672, 37.569309661290504], [127.18122821955262, 37.56636089217979], [127.18169407550688, 37.56286338914073], [127.18408792330152, 37.55814280369575], [127.18350810324185, 37.550053002101485], [127.1852644795464, 37.54888592026534], [127.18480906237207, 37.545296888806796], [127.18543378919821, 37.54260756512178], [127.18364810569703, 37.54241347907019], [127.18116465939269, 37.54384126582126], [127.17770860504257, 37.542414255164374], [127.1744373170213, 37.54277723796397], [127.16830424484573, 37.54145405702079], [127.16530984307447, 37.54221851258693], [127.15566835118616, 37.53119520531309], [127.15538075046105, 37.52652930087977], [127.15154315998161, 37.522828709496416], [127.14981542759394, 37.51926843453025], [127.14791518058246, 37.51918714979303], [127.14684644251928, 37.51661384818575], [127.14672806823502, 37.51415680680291], [127.14532023498624, 37.51464060108829], [127.12123165719615, 37.52528270089], [127.12251496040881, 37.52751810228347], [127.12532464331997, 37.535727879
